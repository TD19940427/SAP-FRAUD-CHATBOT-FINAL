# %%
# COMMAND ----------
# 05 - ORCHESTRATOR

dbutils.notebook.run("00_setup_and_data_load", 0)
dbutils.notebook.run("01_xgboost_fraud_classifier", 0)
dbutils.notebook.run("02_isolation_forest_anomaly", 0)
dbutils.notebook.run("03_risk_scoring_and_logistic_layers", 0)
dbutils.notebook.run("04_time_series_forecasting", 0)

print("✅ Full fraud pipeline completed.")
